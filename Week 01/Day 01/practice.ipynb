# %%
a = "harry Kane"  #A string (Data Type)
b = 32423         #A integer (Data Type)
c= 32423.324      #A Float number (Data type)
d = True          #A Boolean (Data Type)

# %%
print(a)
# Out:
# harry Kane

# %%
print(b)
# Out:
# 32423

# %%
print(c)
# Out:
# 32423.324

# %%
print(d)
# Out:
# True

# %%
d = "123"  #The data type is a string
e = "456"  
f = 123    #The data type is an integer
g = 456

# %%
print(d+e) #The addition operation simply joined the both strings
# Out:
# 123456

# %%
print(f+g) #The addition operation simply added both the intergers
# Out:
# 579

# %%
h = "12.3"
i = "4.56"
j = 3.24
k = 32.4

# %%
print(h+i) #The addition operation simply joined both the float numbers
# Out:
# 12.34.56

# %%
print(j+k) #The addition operation simply added both the float numbers
# Out:
# 35.64

# %%
name = str(input("Enter your name:"))
name1 = int(input("Enter the number:"))
name2 = float(input("Enter the decimal number:"))
name3 = bool(input("3+1=4 , True or False:"))
# Out:
# Enter your name: yamal
# Enter the number: 234
# Enter the decimal number: 78.6
# 3+1=4 , True or False: True

# %%
#Different Print Statements

a = "alex" 
print(a)
print("Hello",a)
print(f"Hello {a}")
# Out:
# alex
# Hello alex
# Hello alex

# %%
a = 2434
b = 768
c= str(a+b)
print(c)
d = str(1111)  #Its a number but we have changed its data type to a string
e = (c+d)
print(e)
# Out:
# 3202
# 32021111

# %%
number = int(input("Enter the Number:"))
if number > 50:
    print("Number is greater than 50.")
elif number == 50:
    print("Number is equal to 50.")
else:
    print("Number is smaller than 50.")
# Out:
# Enter the Number: 67
# Number is greater than 50.

# %%
number = int(input("Enter the Obtained Number:"))
grade = str(input("Enter the Obtained Grade:"))

if (number >= 80 and number <= 100) and grade == "A":
    print("Excellent Performance")
elif (number >= 70 and number <= 79) and grade == "B": 
    print("Good Performance")
elif (number >= 60 and number <= 69) and grade == "C":
    print("Need Improvement")
elif (number >= 50 and number <= 59) and grade == "D":
    print("Poor Performance")
elif (number >= 0 and number <= 49) and grade == "NA":
    print("Fail")
else:
    print("Enter the right obtained numbers or obtained grade.")
# Out:
# Enter the Obtained Number: 79
# Enter the Obtained Grade: B
# Good Performance
